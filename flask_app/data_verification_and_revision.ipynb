# %%
import pickle

# %%
def print_data(file):
    with open(file,'rb') as f:
        d = pickle.load(f)
        print(d.keys())
        return d

# %%
path = '../data/player_stats/'

# %% [markdown]
# ### scatter_plot_matrix of batting and bowling metrics
# ### bowler economy boxplot
# ### top scorers and wicket_takers barchart

# %%
print_data(path+'batsman_metrics.pkl')
# Out:
# dict_keys([2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022])
# ...

# %%
print_data(path+'bowler_metrics.pkl')
# Out:
# dict_keys([2022, 2021, 2020, 2019, 2018, 2017, 2016, 2015, 2014, 2013, 2012, 2011, 2010, 2009, 2008])
# ...

# %%
print_data(path + 'best_economies.pkl')
# Out:
# dict_keys([2022, 2021, 2020, 2019, 2018, 2017, 2016, 2015, 2014, 2013, 2012, 2011, 2010, 2009, 2008])
# ...

# %% [markdown]
# ### multiline graph strike rates

# %%
d = print_data(path + 'top_strike_rates.pkl')
d
# for y in d:
#     for p in d[y]:
#         d[y][p] = [round(val) for val in d[y][p]]
# print(d)
# with open(path+'top_strike_rates.pkl','wb') as tsf:
#     pickle.dump(d, tsf)

# %%
with open(path+'top_strike_rates.pkl','wb') as tsf:
    pickle.dump(d, tsf)
